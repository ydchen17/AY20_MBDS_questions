# %% [markdown]
# Therefore, in our case:
# $$
# \begin{cases}
# r_{ES}=k_1[E][S]-(k_2+k_3)[ES]\\
# r_{E}=-k_1[E][S]+(k_2+k_3)[ES]\\
# r_{S}=-k_1[E][S]+k_2[ES]\\
# r_{P}=k_3[ES]
# \end{cases}
# $$
#
# Given indice that:
#
# $$
# \begin{cases}
# k_{1}=100\\
# k_{2}=600\\
# k_{3}=150\\
# \end{cases}
# $$
#
# With the initial state at:
#
# $$
# \begin{cases}
# [E]_{0}=1 \\
# [S]_{0}=10  \\
# [ES]_{0}=[P]_{0}=0 \\
# \end{cases}
# $$
#
# and
#
# $$
# \begin{cases}
# [ES] = [E]_0 - [{E}]\\
# [P]=[S]_0-[ES]-[S]\\
# \end{cases}
# $$

# %%
# install.packages("deSolve")
library(deSolve)
# help(rk4)
# help(ode.2D)

# %% [markdown]
# Recall that
#
# $$
# E+S\underset{k_2}{\stackrel{k_1}{\rightleftharpoons}}ES{\stackrel{k_3}{\rightarrow}E+P}
# $$

# %%
# Let M=[ES], E=[E], P=[P],S=[S]
MMModel <- function(Time, State, Pars) {
    with(as.list(c(State, Pars)), { 
        
        M = E0 - E
        P = S0 - M - S 
        
        dM <- k1*E*S+(k2+k3)*M
        dE <- -k1*E*S-(k2+k3)*M
        dS <- -k1*E*S+(k2+k3)*M
        dP <- k3*M
        
        return(list(c(dM, dE, dS, dP)))
    })
}

# %%
# Giving our parameters
pars <- c(k1 = 100, k2 = 600, k3 =  150, E0=1, S0=10)

# %%
# Define initial state
yini <- c(E = 1, S = 10, M = 0, P = 0)

# %%
# Define the time sequence, which affects accuracy
times <- seq(0, 0.5, by = 0.001)

# %%
print(system.time(
    out <- ode(func = MMModel, 
               y = yini, 
               parms = pars, 
               times = times)))
# Out:
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.88615e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.88615e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.88615e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.5436e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.5436e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.5436e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.26326e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.26326e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.26326e-19
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 0.00356403, R2 = 1.03383e-19
#
# DLSODA-  Above warning has been issued I1 times.
#      It will not be issued again for this problem.
# In above message, I1 = 10
#
# DLSODA-  At current T (=R1), MXSTEP (=I1) steps
#       taken on this call before reaching TOUT
# In above message, I1 = 5000
#
# In above message, R1 = 0.00356403
# Warning message in lsoda(y, times, func, parms, ...):
# “an excessive amount of work (> maxsteps ) was done, but integration was not successful - increase maxsteps”
# Warning message in lsoda(y, times, func, parms, ...):
# “Returning early. Results are accurate, as far as they go”
#    user  system elapsed
#   0.099   0.000   0.101

# %%
head(out, n = 10)
# Out:
#      time        E              S             M              P
# [1,] 0.000000000   1.000000e+00  1.000000e+01   0.000000e+00   0.0000000
# [2,] 0.001000000   1.766879e+00  9.233121e+00  -1.995664e+00  -0.1228786
# [3,] 0.002000000   3.542897e-02  1.096457e+01  -6.172745e+00  -0.7137316
# [4,] 0.003000000  -1.381713e+01  2.481713e+01  -2.530324e+00  -1.7347456
# [5,] 0.003564033 -1.636445e+146 1.636445e+146  1.636445e+146 498.0138761

# %% [markdown]
# Why this is wrong (to be solved later...)
