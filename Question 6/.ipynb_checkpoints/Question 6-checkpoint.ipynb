# %% [markdown]
# Given a sequence of points that form a polygon, you are required to tell if a list of points are either inside or outside the polygon.

# %% [markdown]
# Example: Given a sequence of points for polygon: (1,1),(1,5),(10,5),(10,1).

# %% [markdown]
# Reference: https://automating-gis-processes.github.io/2016/Lesson3-point-in-polygon.html
