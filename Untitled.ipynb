# %% [markdown]
# Consider a beginning point (a,b) and a destination point (m, n). To arrive from the beginning to the destination, the cost of each move equals to its value in the y axis. Given a total cost of the route, what are the possible routes taken.

# %%
def BFS(start, end, value):
    queue, visited = [start], []
    xrange, yrange = end[0], end[1]
    for i in queue:

# %%
# Out:
# [1, 2, 3, 6, 9]
# [1, 2, 5, 6, 9]
# [1, 2, 5, 8, 9]
# [1, 4, 5, 6, 9]
# [1, 4, 5, 8, 9]
# [1, 4, 7, 8, 9]
